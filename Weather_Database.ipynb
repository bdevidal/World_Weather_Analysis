# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4e59812eddd80a035ba092901a601131

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
       print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | kuusamo
# Processing Record 3 of Set 1 | port macquarie
# Processing Record 4 of Set 1 | garden city
# Processing Record 5 of Set 1 | westport
# Processing Record 6 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | faya
# Processing Record 10 of Set 1 | port hedland
# Processing Record 11 of Set 1 | nantucket
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | geraldton
# Processing Record 15 of Set 1 | palana
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | divnoye
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | ciudad bolivar
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | tynda
# Processing Record 22 of Set 1 | yining
# Processing Record 23 of Set 1 | istanbul
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | beringovskiy
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | castelnaudary
# Processing Record 28 of Set 1 | bonnyville
# Processing Record 29 of Set 1 | sobolevo
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | stornoway
# Processing Record 32 of Set 1 | adrar
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | rocha
# Processing Record 37 of Set 1 | victoria
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | roswell
# Processing Record 44 of Set 1 | patitirion
# Processing Record 45 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 1 | guzelyurt
# Processing Record 47 of Set 1 | jinxiang
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | lavrentiya
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | atyrau
# Processing Record 2 of Set 2 | sao felix do xingu
# Processing Record 3 of Set 2 | rio cauto
# Processing Record 4 of Set 2 | takoradi
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | yerbogachen
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | nanortalik
# Processing Record 9 of Set 2 | narsaq
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | hualmay
# Processing Record 12 of Set 2 | bitung
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | victor harbor
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | teguise
# Processing Record 18 of Set 2 | faanui
# Processing Record 19 of Set 2 | pangnirtung
# Processing Record 20 of Set 2 | ciras
# City not found. Skipping...
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | kahului
# Processing Record 23 of Set 2 | saint anthony
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | fare
# Processing Record 26 of Set 2 | oga
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | naryan-mar
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | college
# Processing Record 32 of Set 2 | anori
# Processing Record 33 of Set 2 | kaduy
# Processing Record 34 of Set 2 | mount isa
# Processing Record 35 of Set 2 | umm kaddadah
# Processing Record 36 of Set 2 | de-kastri
# Processing Record 37 of Set 2 | benicarlo
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | longyearbyen
# Processing Record 40 of Set 2 | joshimath
# Processing Record 41 of Set 2 | kontagora
# Processing Record 42 of Set 2 | mugla
# Processing Record 43 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 2 | sioux lookout
# Processing Record 45 of Set 2 | flin flon
# Processing Record 46 of Set 2 | mandalgovi
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | entre rios
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | santa fe
# Processing Record 2 of Set 3 | pisco
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | dingle
# Processing Record 5 of Set 3 | azatavan
# Processing Record 6 of Set 3 | muroto
# Processing Record 7 of Set 3 | fairbanks
# Processing Record 8 of Set 3 | baykit
# Processing Record 9 of Set 3 | luanda
# Processing Record 10 of Set 3 | bolu
# Processing Record 11 of Set 3 | rundu
# Processing Record 12 of Set 3 | yangambi
# Processing Record 13 of Set 3 | beloha
# Processing Record 14 of Set 3 | hebi
# Processing Record 15 of Set 3 | chipiona
# Processing Record 16 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | binzhou
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | sandwick
# Processing Record 23 of Set 3 | opobo
# City not found. Skipping...
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | carnarvon
# Processing Record 26 of Set 3 | igarka
# Processing Record 27 of Set 3 | lodja
# Processing Record 28 of Set 3 | tuy hoa
# Processing Record 29 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 3 | pousat
# City not found. Skipping...
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | yar-sale
# Processing Record 33 of Set 3 | solnechnyy
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | zemio
# Processing Record 37 of Set 3 | choma
# Processing Record 38 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 3 | kapaa
# Processing Record 40 of Set 3 | miles city
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | ilula
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | pilar
# Processing Record 45 of Set 3 | arkhara
# Processing Record 46 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 3 | ribeira grande
# Processing Record 48 of Set 3 | sinnamary
# Processing Record 49 of Set 3 | russell
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | port lincoln
# Processing Record 2 of Set 4 | ayan
# Processing Record 3 of Set 4 | grootfontein
# Processing Record 4 of Set 4 | tazovskiy
# Processing Record 5 of Set 4 | grindavik
# Processing Record 6 of Set 4 | kuybyshevo
# Processing Record 7 of Set 4 | galle
# Processing Record 8 of Set 4 | souillac
# Processing Record 9 of Set 4 | kariba
# Processing Record 10 of Set 4 | richards bay
# Processing Record 11 of Set 4 | kerema
# Processing Record 12 of Set 4 | tiarei
# Processing Record 13 of Set 4 | cayenne
# Processing Record 14 of Set 4 | saskylakh
# Processing Record 15 of Set 4 | kampene
# Processing Record 16 of Set 4 | matale
# Processing Record 17 of Set 4 | leningradskiy
# Processing Record 18 of Set 4 | san cristobal
# Processing Record 19 of Set 4 | male
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | kalmunai
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | chebsara
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 26 of Set 4 | tilichiki
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | avarua
# Processing Record 29 of Set 4 | eyl
# Processing Record 30 of Set 4 | invermere
# Processing Record 31 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | asfi
# Processing Record 34 of Set 4 | kurilsk
# Processing Record 35 of Set 4 | lompoc
# Processing Record 36 of Set 4 | siguiri
# Processing Record 37 of Set 4 | ternate
# Processing Record 38 of Set 4 | bolshoye kozino
# City not found. Skipping...
# Processing Record 39 of Set 4 | berbera
# Processing Record 40 of Set 4 | opuwo
# Processing Record 41 of Set 4 | sterling
# Processing Record 42 of Set 4 | urucara
# Processing Record 43 of Set 4 | constantine
# Processing Record 44 of Set 4 | norrtalje
# Processing Record 45 of Set 4 | upernavik
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | christchurch
# Processing Record 48 of Set 4 | morant bay
# Processing Record 49 of Set 4 | waterloo
# Processing Record 50 of Set 4 | la rioja
# Processing Record 1 of Set 5 | sindor
# Processing Record 2 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 5 | makurdi
# Processing Record 4 of Set 5 | dongsheng
# Processing Record 5 of Set 5 | hobyo
# Processing Record 6 of Set 5 | puerto baquerizo moreno
# Processing Record 7 of Set 5 | esmeralda
# Processing Record 8 of Set 5 | sambava
# Processing Record 9 of Set 5 | yamethin
# Processing Record 10 of Set 5 | borovoy
# Processing Record 11 of Set 5 | pokhara
# Processing Record 12 of Set 5 | mehamn
# Processing Record 13 of Set 5 | vardo
# Processing Record 14 of Set 5 | meulaboh
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | arlit
# Processing Record 17 of Set 5 | harlingen
# Processing Record 18 of Set 5 | angra
# City not found. Skipping...
# Processing Record 19 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 5 | arraial do cabo
# Processing Record 21 of Set 5 | san quintin
# Processing Record 22 of Set 5 | ilhabela
# Processing Record 23 of Set 5 | whitehorse
# Processing Record 24 of Set 5 | salinopolis
# Processing Record 25 of Set 5 | cuiluan
# Processing Record 26 of Set 5 | najran
# Processing Record 27 of Set 5 | haines junction
# Processing Record 28 of Set 5 | kwinana
# Processing Record 29 of Set 5 | banda aceh
# Processing Record 30 of Set 5 | wukari
# Processing Record 31 of Set 5 | harper
# Processing Record 32 of Set 5 | le port
# Processing Record 33 of Set 5 | mar del plata
# Processing Record 34 of Set 5 | pahrump
# Processing Record 35 of Set 5 | mocuba
# Processing Record 36 of Set 5 | smithers
# Processing Record 37 of Set 5 | razdolnoye
# Processing Record 38 of Set 5 | cidreira
# Processing Record 39 of Set 5 | linchuan
# City not found. Skipping...
# Processing Record 40 of Set 5 | karlskrona
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | povenets
# Processing Record 43 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 5 | severo-kurilsk
# Processing Record 45 of Set 5 | coos bay
# Processing Record 46 of Set 5 | zhongshu
# Processing Record 47 of Set 5 | gidole
# Processing Record 48 of Set 5 | ukiah
# Processing Record 49 of Set 5 | chuy
# Processing Record 50 of Set 5 | labuhan
# Processing Record 1 of Set 6 | ahuimanu
# Processing Record 2 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 6 | kudat
# Processing Record 4 of Set 6 | quatre cocos
# Processing Record 5 of Set 6 | zhigansk
# Processing Record 6 of Set 6 | deder
# Processing Record 7 of Set 6 | norman wells
# Processing Record 8 of Set 6 | balsas
# Processing Record 9 of Set 6 | araouane
# Processing Record 10 of Set 6 | malakal
# Processing Record 11 of Set 6 | coahuayana
# Processing Record 12 of Set 6 | sainte-thecle
# Processing Record 13 of Set 6 | luderitz
# Processing Record 14 of Set 6 | kumluca
# Processing Record 15 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 6 | salamanca
# Processing Record 17 of Set 6 | jizan
# Processing Record 18 of Set 6 | shihezi
# Processing Record 19 of Set 6 | bonavista
# Processing Record 20 of Set 6 | jarjis
# City not found. Skipping...
# Processing Record 21 of Set 6 | balkanabat
# Processing Record 22 of Set 6 | olinda
# Processing Record 23 of Set 6 | vostok
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | manggar
# Processing Record 26 of Set 6 | loudi
# Processing Record 27 of Set 6 | paamiut
# Processing Record 28 of Set 6 | kenora
# Processing Record 29 of Set 6 | winona
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | atbasar
# Processing Record 32 of Set 6 | barra do garcas
# Processing Record 33 of Set 6 | portadown
# Processing Record 34 of Set 6 | angelokhorion
# City not found. Skipping...
# Processing Record 35 of Set 6 | tanout
# Processing Record 36 of Set 6 | mount gambier
# Processing Record 37 of Set 6 | port elizabeth
# Processing Record 38 of Set 6 | vila velha
# Processing Record 39 of Set 6 | vanavara
# Processing Record 40 of Set 6 | marion
# Processing Record 41 of Set 6 | lulea
# Processing Record 42 of Set 6 | seddon
# Processing Record 43 of Set 6 | krasnyy
# Processing Record 44 of Set 6 | daud khel
# Processing Record 45 of Set 6 | ixtapa
# Processing Record 46 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 6 | diffa
# Processing Record 48 of Set 6 | sibolga
# Processing Record 49 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 50 of Set 6 | lima
# Processing Record 1 of Set 7 | la ronge
# Processing Record 2 of Set 7 | hamilton
# Processing Record 3 of Set 7 | saint-pierre
# Processing Record 4 of Set 7 | zaysan
# Processing Record 5 of Set 7 | rennes
# Processing Record 6 of Set 7 | creel
# Processing Record 7 of Set 7 | broome
# Processing Record 8 of Set 7 | camacha
# Processing Record 9 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 7 | tual
# Processing Record 11 of Set 7 | itarema
# Processing Record 12 of Set 7 | alice springs
# Processing Record 13 of Set 7 | fengcheng
# Processing Record 14 of Set 7 | santiago
# Processing Record 15 of Set 7 | ancud
# Processing Record 16 of Set 7 | harbour breton
# Processing Record 17 of Set 7 | karasjok
# Processing Record 18 of Set 7 | bilibino
# Processing Record 19 of Set 7 | auki
# Processing Record 20 of Set 7 | yablonovo
# Processing Record 21 of Set 7 | burgeo
# Processing Record 22 of Set 7 | xining
# Processing Record 23 of Set 7 | songadh
# Processing Record 24 of Set 7 | garowe
# Processing Record 25 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 7 | ahipara
# Processing Record 27 of Set 7 | bure
# Processing Record 28 of Set 7 | raudeberg
# Processing Record 29 of Set 7 | hermsdorf
# Processing Record 30 of Set 7 | ilulissat
# Processing Record 31 of Set 7 | fayaoue
# Processing Record 32 of Set 7 | acapulco
# Processing Record 33 of Set 7 | henties bay
# Processing Record 34 of Set 7 | korla
# Processing Record 35 of Set 7 | sechura
# Processing Record 36 of Set 7 | tahta
# Processing Record 37 of Set 7 | sakaraha
# Processing Record 38 of Set 7 | teya
# Processing Record 39 of Set 7 | zeya
# Processing Record 40 of Set 7 | thompson
# Processing Record 41 of Set 7 | hervey bay
# Processing Record 42 of Set 7 | son la
# Processing Record 43 of Set 7 | paita
# Processing Record 44 of Set 7 | codrington
# Processing Record 45 of Set 7 | bar harbor
# Processing Record 46 of Set 7 | saint george
# Processing Record 47 of Set 7 | rincon
# Processing Record 48 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 49 of Set 7 | nome
# Processing Record 50 of Set 7 | pantai remis
# Processing Record 1 of Set 8 | fort thomas
# Processing Record 2 of Set 8 | gold coast
# Processing Record 3 of Set 8 | port hardy
# Processing Record 4 of Set 8 | ballina
# Processing Record 5 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 8 | monrovia
# Processing Record 7 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 8 | douentza
# Processing Record 9 of Set 8 | la palma
# Processing Record 10 of Set 8 | ust-tsilma
# Processing Record 11 of Set 8 | chikhli
# Processing Record 12 of Set 8 | itoman
# Processing Record 13 of Set 8 | mnogovershinnyy
# Processing Record 14 of Set 8 | hohhot
# Processing Record 15 of Set 8 | verkhnevilyuysk
# Processing Record 16 of Set 8 | chulman
# Processing Record 17 of Set 8 | marystown
# Processing Record 18 of Set 8 | evensk
# Processing Record 19 of Set 8 | provideniya
# Processing Record 20 of Set 8 | thunder bay
# Processing Record 21 of Set 8 | swan hill
# Processing Record 22 of Set 8 | ajdabiya
# Processing Record 23 of Set 8 | ikom
# Processing Record 24 of Set 8 | jacqueville
# Processing Record 25 of Set 8 | namatanai
# Processing Record 26 of Set 8 | warman
# Processing Record 27 of Set 8 | katsuura
# Processing Record 28 of Set 8 | mabaruma
# Processing Record 29 of Set 8 | raposa
# Processing Record 30 of Set 8 | cherskiy
# Processing Record 31 of Set 8 | nadym
# Processing Record 32 of Set 8 | husavik
# Processing Record 33 of Set 8 | port blair
# Processing Record 34 of Set 8 | nouakchott
# Processing Record 35 of Set 8 | caravelas
# Processing Record 36 of Set 8 | beisfjord
# Processing Record 37 of Set 8 | sandakan
# Processing Record 38 of Set 8 | avera
# Processing Record 39 of Set 8 | makakilo city
# Processing Record 40 of Set 8 | andenes
# Processing Record 41 of Set 8 | mazagao
# Processing Record 42 of Set 8 | airai
# Processing Record 43 of Set 8 | darasun
# Processing Record 44 of Set 8 | ostrovnoy
# Processing Record 45 of Set 8 | fethiye
# Processing Record 46 of Set 8 | huron
# Processing Record 47 of Set 8 | carlsbad
# Processing Record 48 of Set 8 | manaus
# Processing Record 49 of Set 8 | deputatskiy
# Processing Record 50 of Set 8 | palmer
# Processing Record 1 of Set 9 | bathsheba
# Processing Record 2 of Set 9 | touros
# Processing Record 3 of Set 9 | guerrero negro
# Processing Record 4 of Set 9 | dzilam gonzalez
# Processing Record 5 of Set 9 | chivilcoy
# Processing Record 6 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 9 | safford
# Processing Record 8 of Set 9 | tera
# Processing Record 9 of Set 9 | billings
# Processing Record 10 of Set 9 | caraballeda
# Processing Record 11 of Set 9 | sao raimundo das mangabeiras
# Processing Record 12 of Set 9 | sao joao da barra
# Processing Record 13 of Set 9 | arteaga
# Processing Record 14 of Set 9 | abalak
# Processing Record 15 of Set 9 | chabahar
# Processing Record 16 of Set 9 | marzuq
# Processing Record 17 of Set 9 | zhigalovo
# Processing Record 18 of Set 9 | katherine
# Processing Record 19 of Set 9 | lovozero
# Processing Record 20 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 9 | bridlington
# Processing Record 22 of Set 9 | aklavik
# Processing Record 23 of Set 9 | chimbote
# Processing Record 24 of Set 9 | nara
# Processing Record 25 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | cabo san lucas
# Processing Record 27 of Set 9 | nelson bay
# Processing Record 28 of Set 9 | kijang
# Processing Record 29 of Set 9 | reefton
# City not found. Skipping...
# Processing Record 30 of Set 9 | grand junction
# Processing Record 31 of Set 9 | odessa
# Processing Record 32 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 9 | thinadhoo
# Processing Record 35 of Set 9 | kavaratti
# Processing Record 36 of Set 9 | tevriz
# Processing Record 37 of Set 9 | sawakin
# Processing Record 38 of Set 9 | tonota
# Processing Record 39 of Set 9 | brunico
# Processing Record 40 of Set 9 | telford
# Processing Record 41 of Set 9 | seoul
# Processing Record 42 of Set 9 | zheleznodorozhnyy
# Processing Record 43 of Set 9 | mogadishu
# Processing Record 44 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 9 | lasa
# Processing Record 46 of Set 9 | de aar
# Processing Record 47 of Set 9 | juneau
# Processing Record 48 of Set 9 | khash
# Processing Record 49 of Set 9 | shache
# Processing Record 50 of Set 9 | aykhal
# Processing Record 1 of Set 10 | dakar
# Processing Record 2 of Set 10 | vigrestad
# Processing Record 3 of Set 10 | dovolnoye
# Processing Record 4 of Set 10 | bam
# Processing Record 5 of Set 10 | sao mateus
# Processing Record 6 of Set 10 | wattegama
# Processing Record 7 of Set 10 | rosarito
# Processing Record 8 of Set 10 | renqiu
# Processing Record 9 of Set 10 | borsad
# Processing Record 10 of Set 10 | idenao
# Processing Record 11 of Set 10 | talnakh
# Processing Record 12 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 10 | bella union
# Processing Record 14 of Set 10 | praia da vitoria
# Processing Record 15 of Set 10 | pangai
# Processing Record 16 of Set 10 | nishihara
# Processing Record 17 of Set 10 | coquimbo
# Processing Record 18 of Set 10 | clyde river
# Processing Record 19 of Set 10 | lianran
# Processing Record 20 of Set 10 | palu
# Processing Record 21 of Set 10 | moskovskiy
# Processing Record 22 of Set 10 | pangobilian
# Processing Record 23 of Set 10 | puerto parra
# Processing Record 24 of Set 10 | colquechaca
# Processing Record 25 of Set 10 | derzhavinsk
# Processing Record 26 of Set 10 | murwara
# Processing Record 27 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 28 of Set 10 | tianpeng
# Processing Record 29 of Set 10 | danjiangkou
# Processing Record 30 of Set 10 | kunming
# Processing Record 31 of Set 10 | gigmoto
# Processing Record 32 of Set 10 | grand gaube
# Processing Record 33 of Set 10 | ipanema
# Processing Record 34 of Set 10 | gimli
# Processing Record 35 of Set 10 | phan thiet
# Processing Record 36 of Set 10 | bardiyah
# Processing Record 37 of Set 10 | angoram
# Processing Record 38 of Set 10 | pinega
# Processing Record 39 of Set 10 | kuala terengganu
# Processing Record 40 of Set 10 | kinkala
# Processing Record 41 of Set 10 | rio gallegos
# Processing Record 42 of Set 10 | polunochnoye
# Processing Record 43 of Set 10 | jishou
# Processing Record 44 of Set 10 | chahuites
# Processing Record 45 of Set 10 | wisconsin rapids
# Processing Record 46 of Set 10 | urozhaynoye
# Processing Record 47 of Set 10 | pijijiapan
# Processing Record 48 of Set 10 | uribia
# Processing Record 49 of Set 10 | duz
# City not found. Skipping...
# Processing Record 50 of Set 10 | isangel
# Processing Record 1 of Set 11 | nayudupeta
# Processing Record 2 of Set 11 | southbridge
# Processing Record 3 of Set 11 | griffith
# Processing Record 4 of Set 11 | tonantins
# Processing Record 5 of Set 11 | zelenoborskiy
# Processing Record 6 of Set 11 | paris
# Processing Record 7 of Set 11 | hammerfest
# Processing Record 8 of Set 11 | vanimo
# Processing Record 9 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 10 of Set 11 | namibe
# Processing Record 11 of Set 11 | sorland
# Processing Record 12 of Set 11 | xam nua
# Processing Record 13 of Set 11 | kipini
# Processing Record 14 of Set 11 | shelburne
# Processing Record 15 of Set 11 | basoda
# Processing Record 16 of Set 11 | anyksciai
# Processing Record 17 of Set 11 | redmond
# Processing Record 18 of Set 11 | murgab
# Processing Record 19 of Set 11 | maragogi
# Processing Record 20 of Set 11 | groton
# Processing Record 21 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 22 of Set 11 | youghal
# Processing Record 23 of Set 11 | pemberton
# Processing Record 24 of Set 11 | musafirkhana
# Processing Record 25 of Set 11 | vanersborg
# Processing Record 26 of Set 11 | xiongzhou
# Processing Record 27 of Set 11 | ginda
# Processing Record 28 of Set 11 | independencia
# Processing Record 29 of Set 11 | novikovo
# Processing Record 30 of Set 11 | nouadhibou
# Processing Record 31 of Set 11 | koulamoutou
# Processing Record 32 of Set 11 | inongo
# Processing Record 33 of Set 11 | fano
# Processing Record 34 of Set 11 | huilong
# Processing Record 35 of Set 11 | portland
# Processing Record 36 of Set 11 | steinbach
# Processing Record 37 of Set 11 | mikuni
# Processing Record 38 of Set 11 | cosamaloapan
# Processing Record 39 of Set 11 | talcahuano
# Processing Record 40 of Set 11 | humberto de campos
# Processing Record 41 of Set 11 | karratha
# Processing Record 42 of Set 11 | roebourne
# Processing Record 43 of Set 11 | boa vista
# Processing Record 44 of Set 11 | tefe
# Processing Record 45 of Set 11 | orocue
# Processing Record 46 of Set 11 | mitsamiouli
# Processing Record 47 of Set 11 | paratinga
# Processing Record 48 of Set 11 | melfi
# Processing Record 49 of Set 11 | komsomolskiy
# Processing Record 50 of Set 11 | indiana
# Processing Record 1 of Set 12 | pataskala
# Processing Record 2 of Set 12 | kaeo
# Processing Record 3 of Set 12 | flinders
# Processing Record 4 of Set 12 | shahreza
# Processing Record 5 of Set 12 | macau
# Processing Record 6 of Set 12 | el alto
# Processing Record 7 of Set 12 | millau
# Processing Record 8 of Set 12 | ketchikan
# Processing Record 9 of Set 12 | saint albans
# Processing Record 10 of Set 12 | moerai
# Processing Record 11 of Set 12 | poso
# Processing Record 12 of Set 12 | hattiesburg
# Processing Record 13 of Set 12 | gat
# Processing Record 14 of Set 12 | puerto escondido
# Processing Record 15 of Set 12 | kruisfontein
# Processing Record 16 of Set 12 | bundaberg
# Processing Record 17 of Set 12 | nikolayevsk-na-amure
# Processing Record 18 of Set 12 | qandala
# Processing Record 19 of Set 12 | manokwari
# Processing Record 20 of Set 12 | payson
# Processing Record 21 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 12 | sept-iles
# Processing Record 23 of Set 12 | datong
# Processing Record 24 of Set 12 | potsdam
# Processing Record 25 of Set 12 | elizabeth city
# Processing Record 26 of Set 12 | huarmey
# Processing Record 27 of Set 12 | naugarzan
# City not found. Skipping...
# Processing Record 28 of Set 12 | berdigestyakh
# Processing Record 29 of Set 12 | ampanihy
# Processing Record 30 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 12 | poum
# Processing Record 32 of Set 12 | massakory
# Processing Record 33 of Set 12 | buraydah
# Processing Record 34 of Set 12 | tadine
# Processing Record 35 of Set 12 | bubaque
# Processing Record 36 of Set 12 | mandalgarh
# Processing Record 37 of Set 12 | bogorodskoye
# Processing Record 38 of Set 12 | kamaishi
# Processing Record 39 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 12 | schiffdorf
# Processing Record 41 of Set 12 | robertsport
# Processing Record 42 of Set 12 | kapit
# Processing Record 43 of Set 12 | cuamba
# Processing Record 44 of Set 12 | ishinomaki
# Processing Record 45 of Set 12 | bongandanga
# Processing Record 46 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 12 | vilhena
# Processing Record 48 of Set 12 | tabou
# Processing Record 49 of Set 12 | teguldet
# Processing Record 50 of Set 12 | port jervis
# Processing Record 1 of Set 13 | shetpe
# Processing Record 2 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 13 | villa carlos paz
# Processing Record 4 of Set 13 | marawi
# Processing Record 5 of Set 13 | las cruces
# Processing Record 6 of Set 13 | fuling
# Processing Record 7 of Set 13 | angoche
# Processing Record 8 of Set 13 | alta
# Processing Record 9 of Set 13 | roros
# Processing Record 10 of Set 13 | pakxan
# Processing Record 11 of Set 13 | siraha
# Processing Record 12 of Set 13 | kulob
# Processing Record 13 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 14 of Set 13 | kupang
# Processing Record 15 of Set 13 | rawson
# Processing Record 16 of Set 13 | dhidhdhoo
# Processing Record 17 of Set 13 | pochutla
# Processing Record 18 of Set 13 | goderich
# Processing Record 19 of Set 13 | okhotsk
# Processing Record 20 of Set 13 | dandong
# Processing Record 21 of Set 13 | eureka
# Processing Record 22 of Set 13 | taybad
# Processing Record 23 of Set 13 | prabumulih
# Processing Record 24 of Set 13 | pitimbu
# Processing Record 25 of Set 13 | comodoro rivadavia
# Processing Record 26 of Set 13 | casas grandes
# Processing Record 27 of Set 13 | pacific grove
# Processing Record 28 of Set 13 | tiznit
# Processing Record 29 of Set 13 | pevek
# Processing Record 30 of Set 13 | general roca
# Processing Record 31 of Set 13 | buin
# Processing Record 32 of Set 13 | denpasar
# Processing Record 33 of Set 13 | lingao
# Processing Record 34 of Set 13 | vilyuysk
# Processing Record 35 of Set 13 | verkhnyaya inta
# Processing Record 36 of Set 13 | kashi
# Processing Record 37 of Set 13 | doha
# Processing Record 38 of Set 13 | calabozo
# Processing Record 39 of Set 13 | berlevag
# Processing Record 40 of Set 13 | keuruu
# Processing Record 41 of Set 13 | bangolo
# Processing Record 42 of Set 13 | burica
# City not found. Skipping...
# Processing Record 43 of Set 13 | sisimiut
# Processing Record 44 of Set 13 | riyadh
# Processing Record 45 of Set 13 | irving
# Processing Record 46 of Set 13 | otorohanga
# Processing Record 47 of Set 13 | mezen
# Processing Record 48 of Set 13 | castanhal
# Processing Record 49 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 50 of Set 13 | nyurba
# Processing Record 1 of Set 14 | listvyanka
# Processing Record 2 of Set 14 | tessalit
# Processing Record 3 of Set 14 | tumpat
# Processing Record 4 of Set 14 | novopskov
# Processing Record 5 of Set 14 | hinton
# Processing Record 6 of Set 14 | manzanillo
# Processing Record 7 of Set 14 | ithaca
# Processing Record 8 of Set 14 | srivardhan
# Processing Record 9 of Set 14 | road town
# Processing Record 10 of Set 14 | tommot
# Processing Record 11 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 14 | estelle
# Processing Record 13 of Set 14 | yulara
# Processing Record 14 of Set 14 | yabrud
# Processing Record 15 of Set 14 | puerto leguizamo
# Processing Record 16 of Set 14 | rio cuarto
# Processing Record 17 of Set 14 | sitka
# Processing Record 18 of Set 14 | tshikapa
# Processing Record 19 of Set 14 | nizhniy kuranakh
# Processing Record 20 of Set 14 | pangoa
# Processing Record 21 of Set 14 | maniitsoq
# Processing Record 22 of Set 14 | balabac
# Processing Record 23 of Set 14 | oranjemund
# Processing Record 24 of Set 14 | tigil
# Processing Record 25 of Set 14 | muros
# Processing Record 26 of Set 14 | hlotse
# Processing Record 27 of Set 14 | delijan
# Processing Record 28 of Set 14 | lalian
# Processing Record 29 of Set 14 | kargalinskaya
# Processing Record 30 of Set 14 | nabire
# Processing Record 31 of Set 14 | sovetskiy
# Processing Record 32 of Set 14 | sistranda
# Processing Record 33 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 34 of Set 14 | dusetos
# Processing Record 35 of Set 14 | umm lajj
# Processing Record 36 of Set 14 | troitskoye
# Processing Record 37 of Set 14 | freeport
# Processing Record 38 of Set 14 | luganville
# Processing Record 39 of Set 14 | fort-shevchenko
# Processing Record 40 of Set 14 | port hueneme
# Processing Record 41 of Set 14 | maningrida
# Processing Record 42 of Set 14 | ottappalam
# Processing Record 43 of Set 14 | viedma
# Processing Record 44 of Set 14 | massaranduba
# Processing Record 45 of Set 14 | olafsvik
# Processing Record 46 of Set 14 | keflavik
# Processing Record 47 of Set 14 | beian
# Processing Record 48 of Set 14 | dori
# Processing Record 49 of Set 14 | acari
# Processing Record 50 of Set 14 | sola
# Processing Record 1 of Set 15 | finschhafen
# Processing Record 2 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 15 | puri
# Processing Record 4 of Set 15 | half moon bay
# Processing Record 5 of Set 15 | kieta
# Processing Record 6 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 15 | constitucion
# Processing Record 8 of Set 15 | atasu
# Processing Record 9 of Set 15 | bereznik
# Processing Record 10 of Set 15 | cockburn town
# Processing Record 11 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 12 of Set 15 | cururupu
# Processing Record 13 of Set 15 | tabuk
# Processing Record 14 of Set 15 | alekseyevsk
# Processing Record 15 of Set 15 | walvis bay
# Processing Record 16 of Set 15 | tartagal
# Processing Record 17 of Set 15 | nioro
# Processing Record 18 of Set 15 | baruun-urt
# Processing Record 19 of Set 15 | saldanha
# Processing Record 20 of Set 15 | porto walter
# Processing Record 21 of Set 15 | borogontsy
# Processing Record 22 of Set 15 | yakovlevka
# Processing Record 23 of Set 15 | anloga
# Processing Record 24 of Set 15 | jalu
# Processing Record 25 of Set 15 | teneguiban
# City not found. Skipping...
# Processing Record 26 of Set 15 | palm coast
# Processing Record 27 of Set 15 | tricase
# Processing Record 28 of Set 15 | naze
# Processing Record 29 of Set 15 | zetea
# Processing Record 30 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 15 | inhambane
# Processing Record 32 of Set 15 | basco
# Processing Record 33 of Set 15 | shimoda
# Processing Record 34 of Set 15 | egvekinot
# Processing Record 35 of Set 15 | tawau
# Processing Record 36 of Set 15 | necochea
# Processing Record 37 of Set 15 | mme
# City not found. Skipping...
# Processing Record 38 of Set 15 | rabo de peixe
# Processing Record 39 of Set 15 | hambantota
# Processing Record 40 of Set 15 | walla walla
# Processing Record 41 of Set 15 | iquique
# Processing Record 42 of Set 15 | vila franca do campo
# Processing Record 43 of Set 15 | sangmelima
# Processing Record 44 of Set 15 | sijunjung
# Processing Record 45 of Set 15 | fairview
# Processing Record 46 of Set 15 | samarai
# Processing Record 47 of Set 15 | tautira
# Processing Record 48 of Set 15 | abu samrah
# Processing Record 49 of Set 15 | kaili
# Processing Record 50 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 1 of Set 16 | sibu
# Processing Record 2 of Set 16 | desbiens
# Processing Record 3 of Set 16 | plettenberg bay
# Processing Record 4 of Set 16 | unye
# City not found. Skipping...
# Processing Record 5 of Set 16 | longido
# Processing Record 6 of Set 16 | francistown
# Processing Record 7 of Set 16 | yaan
# Processing Record 8 of Set 16 | hofn
# Processing Record 9 of Set 16 | coihaique
# Processing Record 10 of Set 16 | aksu
# Processing Record 11 of Set 16 | mabai
# Processing Record 12 of Set 16 | jaicos
# Processing Record 13 of Set 16 | praia
# Processing Record 14 of Set 16 | eten
# Processing Record 15 of Set 16 | babino
# Processing Record 16 of Set 16 | shingu
# Processing Record 17 of Set 16 | yershov
# Processing Record 18 of Set 16 | lerwick
# Processing Record 19 of Set 16 | buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 705

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Kuusamo  65.97   29.18     32.00        90          90       10.29
# 1  Port Macquarie -31.43  152.92     70.00        46          13       11.41
# 2     Garden City  42.33  -83.33     57.99        71           1        5.82
# 3        Westport  41.14  -73.36     48.20        87           1        2.73
# 4         Ushuaia -54.80  -68.30     39.20        94          75       17.22
# 5    Puerto Ayora  -0.74  -90.35     68.00        89          44        1.99
# 6            Faya  18.39   42.45     66.20        39           0        4.63
# 7    Port Hedland -20.32  118.57     95.00        23           0       19.46
# 8       Nantucket  41.28  -70.10     48.20        93           1        3.36
# 9      Bredasdorp -34.53   20.04     53.60        66           2        8.05
#
#   Country Current Description
# 0      FI     overcast clouds
# 1      AU          few clouds
# 2      US           clear sky
# 3      US           clear sky
# 4      AR       broken clouds
# 5      EC    scattered clouds
# 6      SA           clear sky
# 7      AU           clear sky
# 8      US                 fog
# 9      ZA           clear sky

# %%
# Reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kuusamo      FI  65.97   29.18     32.00        90          90
# 1  Port Macquarie      AU -31.43  152.92     70.00        46          13
# 2     Garden City      US  42.33  -83.33     57.99        71           1
# 3        Westport      US  41.14  -73.36     48.20        87           1
# 4         Ushuaia      AR -54.80  -68.30     39.20        94          75
# 5    Puerto Ayora      EC  -0.74  -90.35     68.00        89          44
# 6            Faya      SA  18.39   42.45     66.20        39           0
# 7    Port Hedland      AU -20.32  118.57     95.00        23           0
# 8       Nantucket      US  41.28  -70.10     48.20        93           1
# 9      Bredasdorp      ZA -34.53   20.04     53.60        66           2
#
#    Wind Speed Current Description
# 0       10.29     overcast clouds
# 1       11.41          few clouds
# 2        5.82           clear sky
# 3        2.73           clear sky
# 4       17.22       broken clouds
# 5        1.99    scattered clouds
# 6        4.63           clear sky
# 7       19.46           clear sky
# 8        3.36                 fog
# 9        8.05           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
